# %% [markdown]
# # GAN - Queremos o Gerador

# %% [markdown]
# Tens duas redes:
#
# - `Gerador (G):` recebe ruído aleatório e cria imagens falsas
#
# - `Discriminador (D):` recebe imagens e tenta dizer se são reais ou falsas
#
# Durante o treino, em cada batch, as imagens circulam assim:
#
# 1. um batch de imagens reais vai para o discriminador
#
# 2. um batch de ruído aleatório vai para o gerador
#
# 3. o gerador produz imagens falsas
#
# 4. essas imagens falsas também vão para o discriminador
#
# 5. primeiro atualizas o discriminador
#
# 6. depois atualizas o gerador

# %%
print("teste")
# Out:
# teste

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.utils import save_image, make_grid

from wiki_gan_dataset import build_wiki_gan_dataloader, get_dcgan_transform

# %% [markdown]
# ## Configuração

# %%
# =========================================================
# Configuração
# =========================================================
REAL_DIR = "../deepfake_data/wiki"
OUTPUT_DIR = "outputs"
SAMPLES_DIR = os.path.join(OUTPUT_DIR, "samples")
CHECKPOINTS_DIR = os.path.join(OUTPUT_DIR, "checkpoints")

IMAGE_SIZE = 64
BATCH_SIZE = 64
LATENT_DIM = 100    # Tamanho do vetor aleatório que entra no gerador
NGF = 64    # Número base de filtros do gerador
NDF = 64    # Número base de filtros do discriminador
NUM_CHANNELS = 3    # 3 channels porque estou a usar RGB

# Parametros de treino
NUM_EPOCHS = 50
LR_G = 2e-4     # Learning rate do gerador
LR_D = 1e-4     # Learning rate do discriminador
BETA1 = 0.5     # Hiperparametro do Adam (é um valor clássico em DCGAN)
SEED = 42
NUM_WORKERS = 2     # Número de workers no DataLoader

# Que folds usar
START_FOLD = 0
END_FOLD = 5
INTERVAL = True

# Usar CUDA para ser mais rápido
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PIN_MEMORY = DEVICE.type == "cuda"

# Crias as pastas dos outputs
os.makedirs(SAMPLES_DIR, exist_ok=True)
os.makedirs(CHECKPOINTS_DIR, exist_ok=True)

# Torna o treino mais consistente entre execuções
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print("Device:", DEVICE)
# Out:
# Device: cuda

# %% [markdown]
# ## Dataset e DataLoader

# %%
transform = get_dcgan_transform(image_size=IMAGE_SIZE)

dataset, dataloader = build_wiki_gan_dataloader(
    img_dir=REAL_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    range_folds=(START_FOLD, END_FOLD),
    interval=INTERVAL,
    shuffle=True,
    drop_last=True,
)

print(f"Total de imagens reais: {len(dataset)}")
print(f"Folds usados: {dataset.fold_names}")
# Out:
# Total de imagens reais: 1467
# Folds usados: ['00', '01', '02', '03', '04']

# %% [markdown]
# ### Ver uma imagem do dataset

# %%
dataset.show(0)

# %% [markdown]
# ### Inicialização de pesos

# %%
# Esta função inicializa os pesos da rede, se for:
# - Camada convolucional: inicializa os pesos com distribuição normal (média 0 e desvio padrão 0.02)
# - Camada BatchNorm: pesos perto de 1 e bias 0 
def weights_init(m):
    classname = m.__class__.__name__
    if "Conv" in classname:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif "BatchNorm" in classname:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
# Isto é o tipo de inicialização clássica em DCGAN

# %% [markdown]
# # Gerador

# %%
# O Gerador recebe um vetor aleatório z e tenta convertê-lo numa imagem falsa realista
class Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf=64, nc=3):
        super().__init__()

        self.init = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
        )

        self.main = nn.Sequential(
            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 8, ngf * 4, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 4, ngf * 2, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 2, ngf, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf, nc, 3, 1, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        x = self.init(z)
        return self.main(x)

# %% [markdown]
# # Discriminador

# %%
# Recebe uma imagem e tenta dizer se ela é real ou falsa
# Ele faz o oposto do gerador, reduz progressivamente a resolução, aumentando profundidade e no fim produz um único valor por imagem
class Discriminator(nn.Module):
    def __init__(self, nc=3, ndf=64):
        super().__init__()
        self.main = nn.Sequential(
            # 64x64 -> 32x32
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            # 32x32 -> 16x16
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),

            # 16x16 -> 8x8
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),

            # 8x8 -> 4x4
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),

            # 4x4 -> 1x1
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False)
        )

    def forward(self, x):
        return self.main(x).view(-1)

# %% [markdown]
# # Instanciar modelos

# %%
netG = Generator(LATENT_DIM, NGF, NUM_CHANNELS).to(DEVICE)
netD = Discriminator(NUM_CHANNELS, NDF).to(DEVICE)

netG.apply(weights_init)
netD.apply(weights_init)

print(netG)
print(netD)
# Out:
# Generator(
#   (init): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (main): Sequential(
#     (0): Upsample(scale_factor=2.0, mode='nearest')
#     (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Upsample(scale_factor=2.0, mode='nearest')
#     (5): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#     (8): Upsample(scale_factor=2.0, mode='nearest')
#     (9): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): Upsample(scale_factor=2.0, mode='nearest')
#     (13): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (14): Tanh()
#   )
# )
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   )
# )

# %%
# Loss binária com logits
# O discriminador devolve logits crus, sem sigmoid, esta loss combina sigmoid e binary cross entropy de forma mais estavel numericamente
criterion = nn.BCEWithLogitsLoss()

# Otimizadores Adam para o discriminador e o gerador
optimizerD = optim.Adam(netD.parameters(), lr=LR_D, betas=(BETA1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=LR_G, betas=(BETA1, 0.999))

# Ruido fixo para as amostras. Este ruido serve para gerar sempre as mesmas 64 imagens ao longo do treino.
# Deste modo podemos ver a evolução do gerador de forma consistente (na epoch 1, 10, 50, etc)
fixed_noise = torch.randn(64, LATENT_DIM, 1, 1, device=DEVICE)

# %% [markdown]
# ## Função para guardar amostras

# %%
def save_generated_samples(epoch, generator, noise):
    generator.eval()
    with torch.no_grad():
        fake_images = generator(noise).detach().cpu()
        fake_images = (fake_images + 1) / 2  # [-1,1] -> [0,1]
        grid = make_grid(fake_images, nrow=8, padding=2, normalize=False)
        save_image(grid, os.path.join(SAMPLES_DIR, f"epoch_{epoch:03d}.png"))
    generator.train()

# %% [markdown]
# ## Treino

# %%
import pandas as pd
history = []
g_losses = []
d_losses = []

print("A começar treino...")

for epoch in range(1, NUM_EPOCHS + 1):
    epoch_g_loss = 0.0
    epoch_d_loss = 0.0
    epoch_dx = 0.0
    epoch_dgz_fake = 0.0
    epoch_dgz_gen = 0.0

    for i, real_images in enumerate(dataloader):
        real_images = real_images.to(DEVICE)
        b_size = real_images.size(0)

        # -----------------------------------------
        # 1. Treinar Discriminador
        # -----------------------------------------
        netD.zero_grad(set_to_none=True)

        labels_real = torch.ones(b_size, device=DEVICE)
        output_real = netD(real_images)
        lossD_real = criterion(output_real, labels_real)

        noise = torch.randn(b_size, LATENT_DIM, 1, 1, device=DEVICE)
        fake_images = netG(noise)

        labels_fake = torch.zeros(b_size, device=DEVICE)
        output_fake = netD(fake_images.detach())
        lossD_fake = criterion(output_fake, labels_fake)

        lossD = lossD_real + lossD_fake
        lossD.backward()
        optimizerD.step()

        # -----------------------------------------
        # 2. Treinar Gerador
        # -----------------------------------------
        netG.zero_grad(set_to_none=True)

        labels_gen = torch.ones(b_size, device=DEVICE)
        output_gen = netD(fake_images)
        lossG = criterion(output_gen, labels_gen)
        lossG.backward()
        optimizerG.step()

        epoch_d_loss += lossD.item()
        epoch_g_loss += lossG.item()

        epoch_dx += torch.sigmoid(output_real).mean().item()
        epoch_dgz_fake += torch.sigmoid(output_fake).mean().item()
        epoch_dgz_gen += torch.sigmoid(output_gen).mean().item()

        if i % 50 == 0:
            print(
                f"[Epoch {epoch}/{NUM_EPOCHS}] "
                f"[Batch {i}/{len(dataloader)}] "
                f"Loss_D: {lossD.item():.4f} "
                f"Loss_G: {lossG.item():.4f} "
                f"D(x): {torch.sigmoid(output_real).mean().item():.4f} "
                f"D(G(z)): {torch.sigmoid(output_fake).mean().item():.4f}/"
                f"{torch.sigmoid(output_gen).mean().item():.4f}"
            )

    avg_d = epoch_d_loss / len(dataloader)
    avg_g = epoch_g_loss / len(dataloader)
    avg_dx = epoch_dx / len(dataloader)
    avg_dgz_fake = epoch_dgz_fake / len(dataloader)
    avg_dgz_gen = epoch_dgz_gen / len(dataloader)

    d_losses.append(avg_d)
    g_losses.append(avg_g)

    history.append({
        "epoch": epoch,
        "loss_d": avg_d,
        "loss_g": avg_g,
        "D_x": avg_dx,
        "D_G_z_fake": avg_dgz_fake,
        "D_G_z_gen": avg_dgz_gen,
    })

    print(
        f"==> Epoch {epoch}: "
        f"avg Loss_D={avg_d:.4f}, "
        f"avg Loss_G={avg_g:.4f}, "
        f"avg D(x)={avg_dx:.4f}, "
        f"avg D(G(z)) fake={avg_dgz_fake:.4f}, "
        f"avg D(G(z)) gen={avg_dgz_gen:.4f}"
    )

    save_generated_samples(epoch, netG, fixed_noise)

    history_df = pd.DataFrame(history)
    history_df.to_csv(os.path.join(OUTPUT_DIR, "training_history.csv"), index=False)

    torch.save({
        "epoch": epoch,
        "netG_state_dict": netG.state_dict(),
        "netD_state_dict": netD.state_dict(),
        "optimizerG_state_dict": optimizerG.state_dict(),
        "optimizerD_state_dict": optimizerD.state_dict(),
        "g_losses": g_losses,
        "d_losses": d_losses,
        "history": history,
        "folds_used": dataset.fold_names,
        "real_dir": REAL_DIR,
    }, os.path.join(CHECKPOINTS_DIR, f"dcgan_epoch_{epoch:03d}.pt"))

print("Treino terminado.")
# Out:
# A começar treino...
# [Epoch 1/50] [Batch 0/22] Loss_D: 0.9550 Loss_G: 6.4269 D(x): 0.6360 D(G(z)): 0.1670/0.0031
# ==> Epoch 1: avg Loss_D=1.3403, avg Loss_G=6.1837, avg D(x)=0.6655, avg D(G(z)) fake=0.3546, avg D(G(z)) gen=0.0099
# [Epoch 2/50] [Batch 0/22] Loss_D: 1.1896 Loss_G: 4.7415 D(x): 0.7645 D(G(z)): 0.4171/0.0391
# ==> Epoch 2: avg Loss_D=1.4448, avg Loss_G=4.1692, avg D(x)=0.6531, avg D(G(z)) fake=0.3702, avg D(G(z)) gen=0.0509
# [Epoch 3/50] [Batch 0/22] Loss_D: 2.1023 Loss_G: 3.3950 D(x): 0.4212 D(G(z)): 0.3936/0.0884
# ==> Epoch 3: avg Loss_D=1.1917, avg Loss_G=3.0794, avg D(x)=0.6463, avg D(G(z)) fake=0.3295, avg D(G(z)) gen=0.0976
# [Epoch 4/50] [Batch 0/22] Loss_D: 0.9549 Loss_G: 3.0202 D(x): 0.7146 D(G(z)): 0.3407/0.0815
# ==> Epoch 4: avg Loss_D=1.1388, avg Loss_G=2.6905, avg D(x)=0.6457, avg D(G(z)) fake=0.3407, avg D(G(z)) gen=0.1322
# [Epoch 5/50] [Batch 0/22] Loss_D: 1.0040 Loss_G: 2.0337 D(x): 0.7006 D(G(z)): 0.3679/0.1820
# ==> Epoch 5: avg Loss_D=1.0500, avg Loss_G=2.2276, avg D(x)=0.6428, avg D(G(z)) fake=0.3483, avg D(G(z)) gen=0.1558
# [Epoch 6/50] [Batch 0/22] Loss_D: 0.8852 Loss_G: 2.4737 D(x): 0.7600 D(G(z)): 0.3619/0.1368
# ==> Epoch 6: avg Loss_D=1.1224, avg Loss_G=2.6483, avg D(x)=0.6472, avg D(G(z)) fake=0.3688, avg D(G(z)) gen=0.1126
# [Epoch 7/50] [Batch 0/22] Loss_D: 1.1423 Loss_G: 2.6026 D(x): 0.5788 D(G(z)): 0.3261/0.1237
# ==> Epoch 7: avg Loss_D=1.1748, avg Loss_G=2.5823, avg D(x)=0.6246, avg D(G(z)) fake=0.3715, avg D(G(z)) gen=0.1209
# [Epoch 8/50] [Batch 0/22] Loss_D: 1.0818 Loss_G: 2.9561 D(x): 0.7127 D(G(z)): 0.4104/0.1098
# ==> Epoch 8: avg Loss_D=1.3041, avg Loss_G=2.3277, avg D(x)=0.6016, avg D(G(z)) fake=0.4094, avg D(G(z)) gen=0.1505
# [Epoch 9/50] [Batch 0/22] Loss_D: 1.3081 Loss_G: 2.9294 D(x): 0.5971 D(G(z)): 0.4038/0.0964
# ==> Epoch 9: avg Loss_D=1.2694, avg Loss_G=2.5228, avg D(x)=0.5991, avg D(G(z)) fake=0.3995, avg D(G(z)) gen=0.1290
# [Epoch 10/50] [Batch 0/22] Loss_D: 1.5311 Loss_G: 2.2881 D(x): 0.5069 D(G(z)): 0.4389/0.1426
# ==> Epoch 10: avg Loss_D=1.2096, avg Loss_G=2.4723, avg D(x)=0.6089, avg D(G(z)) fake=0.3795, avg D(G(z)) gen=0.1307
# [Epoch 11/50] [Batch 0/22] Loss_D: 1.1151 Loss_G: 2.9501 D(x): 0.6945 D(G(z)): 0.4155/0.0853
# ==> Epoch 11: avg Loss_D=1.0935, avg Loss_G=2.6468, avg D(x)=0.6347, avg D(G(z)) fake=0.3593, avg D(G(z)) gen=0.1082
# [Epoch 12/50] [Batch 0/22] Loss_D: 0.7336 Loss_G: 2.5055 D(x): 0.7707 D(G(z)): 0.3095/0.1124
# ==> Epoch 12: avg Loss_D=0.8997, avg Loss_G=2.2813, avg D(x)=0.6753, avg D(G(z)) fake=0.3203, avg D(G(z)) gen=0.1416
# [Epoch 13/50] [Batch 0/22] Loss_D: 0.7200 Loss_G: 2.4125 D(x): 0.8011 D(G(z)): 0.3330/0.1248
# ==> Epoch 13: avg Loss_D=0.8655, avg Loss_G=2.2886, avg D(x)=0.6919, avg D(G(z)) fake=0.3130, avg D(G(z)) gen=0.1384
# [Epoch 14/50] [Batch 0/22] Loss_D: 0.9166 Loss_G: 2.5726 D(x): 0.6809 D(G(z)): 0.3374/0.1114
# ==> Epoch 14: avg Loss_D=0.9087, avg Loss_G=2.4819, avg D(x)=0.6766, avg D(G(z)) fake=0.3177, avg D(G(z)) gen=0.1201
# [Epoch 15/50] [Batch 0/22] Loss_D: 0.7924 Loss_G: 2.2300 D(x): 0.6759 D(G(z)): 0.2519/0.1435
# ==> Epoch 15: avg Loss_D=0.7555, avg Loss_G=2.2547, avg D(x)=0.7161, avg D(G(z)) fake=0.2799, avg D(G(z)) gen=0.1396
# [Epoch 16/50] [Batch 0/22] Loss_D: 0.8415 Loss_G: 2.2151 D(x): 0.7149 D(G(z)): 0.3314/0.1576
# ==> Epoch 16: avg Loss_D=0.8014, avg Loss_G=2.3191, avg D(x)=0.7079, avg D(G(z)) fake=0.2985, avg D(G(z)) gen=0.1338
# [Epoch 17/50] [Batch 0/22] Loss_D: 0.7416 Loss_G: 2.4560 D(x): 0.7232 D(G(z)): 0.2968/0.1098
# ==> Epoch 17: avg Loss_D=0.7551, avg Loss_G=2.3672, avg D(x)=0.7184, avg D(G(z)) fake=0.2860, avg D(G(z)) gen=0.1288
# [Epoch 18/50] [Batch 0/22] Loss_D: 0.8112 Loss_G: 1.9966 D(x): 0.5931 D(G(z)): 0.1827/0.1748
# ==> Epoch 18: avg Loss_D=0.7230, avg Loss_G=2.3143, avg D(x)=0.7231, avg D(G(z)) fake=0.2759, avg D(G(z)) gen=0.1305
# [Epoch 19/50] [Batch 0/22] Loss_D: 0.6132 Loss_G: 2.6642 D(x): 0.8108 D(G(z)): 0.2998/0.0894
# ==> Epoch 19: avg Loss_D=0.6514, avg Loss_G=2.4981, avg D(x)=0.7480, avg D(G(z)) fake=0.2510, avg D(G(z)) gen=0.1137
# [Epoch 20/50] [Batch 0/22] Loss_D: 0.6397 Loss_G: 2.4092 D(x): 0.6935 D(G(z)): 0.1878/0.1188
# ==> Epoch 20: avg Loss_D=0.6788, avg Loss_G=2.4726, avg D(x)=0.7363, avg D(G(z)) fake=0.2550, avg D(G(z)) gen=0.1182
# [Epoch 21/50] [Batch 0/22] Loss_D: 0.6157 Loss_G: 2.6171 D(x): 0.7419 D(G(z)): 0.2255/0.1076
# ==> Epoch 21: avg Loss_D=0.7777, avg Loss_G=2.5257, avg D(x)=0.7159, avg D(G(z)) fake=0.2897, avg D(G(z)) gen=0.1177
# [Epoch 22/50] [Batch 0/22] Loss_D: 0.6532 Loss_G: 2.3039 D(x): 0.7216 D(G(z)): 0.2361/0.1258
# ==> Epoch 22: avg Loss_D=0.8337, avg Loss_G=2.5060, avg D(x)=0.7046, avg D(G(z)) fake=0.2970, avg D(G(z)) gen=0.1267
# [Epoch 23/50] [Batch 0/22] Loss_D: 0.7555 Loss_G: 3.6285 D(x): 0.7700 D(G(z)): 0.3091/0.0469
# ==> Epoch 23: avg Loss_D=0.8617, avg Loss_G=2.4992, avg D(x)=0.6885, avg D(G(z)) fake=0.2979, avg D(G(z)) gen=0.1233
# [Epoch 24/50] [Batch 0/22] Loss_D: 0.7145 Loss_G: 3.1425 D(x): 0.8296 D(G(z)): 0.3382/0.0702
# ==> Epoch 24: avg Loss_D=0.7704, avg Loss_G=2.6546, avg D(x)=0.7231, avg D(G(z)) fake=0.2827, avg D(G(z)) gen=0.1050
# [Epoch 25/50] [Batch 0/22] Loss_D: 0.9514 Loss_G: 2.9683 D(x): 0.7051 D(G(z)): 0.3752/0.0743
# ==> Epoch 25: avg Loss_D=0.7763, avg Loss_G=2.5895, avg D(x)=0.7173, avg D(G(z)) fake=0.2838, avg D(G(z)) gen=0.1117
# [Epoch 26/50] [Batch 0/22] Loss_D: 0.7362 Loss_G: 2.8990 D(x): 0.7711 D(G(z)): 0.3055/0.0897
# ==> Epoch 26: avg Loss_D=0.6412, avg Loss_G=2.6554, avg D(x)=0.7538, avg D(G(z)) fake=0.2435, avg D(G(z)) gen=0.1038
# [Epoch 27/50] [Batch 0/22] Loss_D: 0.6515 Loss_G: 2.5256 D(x): 0.7658 D(G(z)): 0.2674/0.1071
# ==> Epoch 27: avg Loss_D=0.6483, avg Loss_G=2.4365, avg D(x)=0.7556, avg D(G(z)) fake=0.2541, avg D(G(z)) gen=0.1208
# [Epoch 28/50] [Batch 0/22] Loss_D: 0.4710 Loss_G: 2.5136 D(x): 0.7636 D(G(z)): 0.1483/0.0997
# ==> Epoch 28: avg Loss_D=0.6347, avg Loss_G=2.3234, avg D(x)=0.7503, avg D(G(z)) fake=0.2411, avg D(G(z)) gen=0.1347
# [Epoch 29/50] [Batch 0/22] Loss_D: 0.5497 Loss_G: 2.6094 D(x): 0.8137 D(G(z)): 0.2581/0.0896
# ==> Epoch 29: avg Loss_D=0.5659, avg Loss_G=2.4702, avg D(x)=0.7780, avg D(G(z)) fake=0.2287, avg D(G(z)) gen=0.1118
# [Epoch 30/50] [Batch 0/22] Loss_D: 0.5549 Loss_G: 2.1742 D(x): 0.7112 D(G(z)): 0.1586/0.1467
# ==> Epoch 30: avg Loss_D=0.5428, avg Loss_G=2.4709, avg D(x)=0.7766, avg D(G(z)) fake=0.2140, avg D(G(z)) gen=0.1149
# [Epoch 31/50] [Batch 0/22] Loss_D: 0.5584 Loss_G: 3.5303 D(x): 0.8695 D(G(z)): 0.2993/0.0397
# ==> Epoch 31: avg Loss_D=0.6191, avg Loss_G=2.6029, avg D(x)=0.7608, avg D(G(z)) fake=0.2406, avg D(G(z)) gen=0.1102
# [Epoch 32/50] [Batch 0/22] Loss_D: 1.0201 Loss_G: 4.4355 D(x): 0.8813 D(G(z)): 0.5103/0.0177
# ==> Epoch 32: avg Loss_D=0.6677, avg Loss_G=2.7504, avg D(x)=0.7520, avg D(G(z)) fake=0.2506, avg D(G(z)) gen=0.0994
# [Epoch 33/50] [Batch 0/22] Loss_D: 0.3752 Loss_G: 2.9618 D(x): 0.8416 D(G(z)): 0.1673/0.0674
# ==> Epoch 33: avg Loss_D=0.5457, avg Loss_G=2.6378, avg D(x)=0.7799, avg D(G(z)) fake=0.2160, avg D(G(z)) gen=0.1008
# [Epoch 34/50] [Batch 0/22] Loss_D: 0.4316 Loss_G: 2.8531 D(x): 0.8442 D(G(z)): 0.1962/0.0819
# ==> Epoch 34: avg Loss_D=0.5050, avg Loss_G=2.5164, avg D(x)=0.7966, avg D(G(z)) fake=0.2066, avg D(G(z)) gen=0.1109
# [Epoch 35/50] [Batch 0/22] Loss_D: 0.4074 Loss_G: 2.7921 D(x): 0.8296 D(G(z)): 0.1827/0.0786
# ==> Epoch 35: avg Loss_D=0.4873, avg Loss_G=2.6327, avg D(x)=0.8027, avg D(G(z)) fake=0.1996, avg D(G(z)) gen=0.1047
# [Epoch 36/50] [Batch 0/22] Loss_D: 0.4783 Loss_G: 2.5871 D(x): 0.7234 D(G(z)): 0.1006/0.1084
# ==> Epoch 36: avg Loss_D=0.5950, avg Loss_G=2.7882, avg D(x)=0.7730, avg D(G(z)) fake=0.2247, avg D(G(z)) gen=0.1022
# [Epoch 37/50] [Batch 0/22] Loss_D: 0.5749 Loss_G: 3.3998 D(x): 0.7860 D(G(z)): 0.2383/0.0471
# ==> Epoch 37: avg Loss_D=0.5301, avg Loss_G=2.9065, avg D(x)=0.7883, avg D(G(z)) fake=0.2085, avg D(G(z)) gen=0.0848
# [Epoch 38/50] [Batch 0/22] Loss_D: 0.3756 Loss_G: 2.6537 D(x): 0.8323 D(G(z)): 0.1503/0.0911
# ==> Epoch 38: avg Loss_D=0.4901, avg Loss_G=2.8056, avg D(x)=0.8024, avg D(G(z)) fake=0.1968, avg D(G(z)) gen=0.0885
# [Epoch 39/50] [Batch 0/22] Loss_D: 0.3965 Loss_G: 2.7846 D(x): 0.8283 D(G(z)): 0.1724/0.0792
# ==> Epoch 39: avg Loss_D=0.5010, avg Loss_G=2.7419, avg D(x)=0.7956, avg D(G(z)) fake=0.1948, avg D(G(z)) gen=0.1022
# [Epoch 40/50] [Batch 0/22] Loss_D: 0.6673 Loss_G: 3.7431 D(x): 0.9260 D(G(z)): 0.3907/0.0361
# ==> Epoch 40: avg Loss_D=0.4813, avg Loss_G=2.8876, avg D(x)=0.8112, avg D(G(z)) fake=0.1978, avg D(G(z)) gen=0.0824
# [Epoch 41/50] [Batch 0/22] Loss_D: 0.3063 Loss_G: 3.3097 D(x): 0.8744 D(G(z)): 0.1470/0.0487
# ==> Epoch 41: avg Loss_D=0.4194, avg Loss_G=2.7481, avg D(x)=0.8258, avg D(G(z)) fake=0.1747, avg D(G(z)) gen=0.0921
# [Epoch 42/50] [Batch 0/22] Loss_D: 0.3550 Loss_G: 2.5629 D(x): 0.8188 D(G(z)): 0.1301/0.0889
# ==> Epoch 42: avg Loss_D=0.3746, avg Loss_G=2.7996, avg D(x)=0.8391, avg D(G(z)) fake=0.1568, avg D(G(z)) gen=0.0854
# [Epoch 43/50] [Batch 0/22] Loss_D: 0.3790 Loss_G: 2.6193 D(x): 0.8347 D(G(z)): 0.1599/0.0884
# ==> Epoch 43: avg Loss_D=0.3638, avg Loss_G=2.8036, avg D(x)=0.8423, avg D(G(z)) fake=0.1545, avg D(G(z)) gen=0.0811
# [Epoch 44/50] [Batch 0/22] Loss_D: 0.3369 Loss_G: 3.2921 D(x): 0.9204 D(G(z)): 0.2053/0.0516
# ==> Epoch 44: avg Loss_D=0.3733, avg Loss_G=2.8815, avg D(x)=0.8413, avg D(G(z)) fake=0.1571, avg D(G(z)) gen=0.0830
# [Epoch 45/50] [Batch 0/22] Loss_D: 0.3997 Loss_G: 3.7071 D(x): 0.9267 D(G(z)): 0.2521/0.0333
# ==> Epoch 45: avg Loss_D=0.6917, avg Loss_G=3.2715, avg D(x)=0.7902, avg D(G(z)) fake=0.2227, avg D(G(z)) gen=0.1379
# [Epoch 46/50] [Batch 0/22] Loss_D: 0.8033 Loss_G: 3.4869 D(x): 0.6860 D(G(z)): 0.2374/0.0588
# ==> Epoch 46: avg Loss_D=0.4996, avg Loss_G=3.2416, avg D(x)=0.8001, avg D(G(z)) fake=0.1882, avg D(G(z)) gen=0.0649
# [Epoch 47/50] [Batch 0/22] Loss_D: 0.2716 Loss_G: 3.3337 D(x): 0.8959 D(G(z)): 0.1378/0.0470
# ==> Epoch 47: avg Loss_D=0.3574, avg Loss_G=2.9641, avg D(x)=0.8464, avg D(G(z)) fake=0.1504, avg D(G(z)) gen=0.0723
# [Epoch 48/50] [Batch 0/22] Loss_D: 0.3691 Loss_G: 3.8236 D(x): 0.9337 D(G(z)): 0.2375/0.0295
# ==> Epoch 48: avg Loss_D=0.3269, avg Loss_G=2.9264, avg D(x)=0.8607, avg D(G(z)) fake=0.1423, avg D(G(z)) gen=0.0750
# [Epoch 49/50] [Batch 0/22] Loss_D: 0.2227 Loss_G: 3.2629 D(x): 0.8892 D(G(z)): 0.0939/0.0525
# ==> Epoch 49: avg Loss_D=0.2852, avg Loss_G=2.8789, avg D(x)=0.8734, avg D(G(z)) fake=0.1266, avg D(G(z)) gen=0.0744
# [Epoch 50/50] [Batch 0/22] Loss_D: 0.2780 Loss_G: 2.7787 D(x): 0.8418 D(G(z)): 0.0901/0.0820
# ==> Epoch 50: avg Loss_D=0.2894, avg Loss_G=2.8723, avg D(x)=0.8702, avg D(G(z)) fake=0.1262, avg D(G(z)) gen=0.0756
# Treino terminado.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

history_path = os.path.join(OUTPUT_DIR, "training_history.csv")
history_df = pd.read_csv(history_path)

plt.figure(figsize=(10, 5))
plt.plot(history_df["epoch"], history_df["loss_g"], label="Generator Loss")
plt.plot(history_df["epoch"], history_df["loss_d"], label="Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("GAN Training Losses")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history_df["epoch"], history_df["D_x"], label="D(x)")
plt.plot(history_df["epoch"], history_df["D_G_z_fake"], label="D(G(z)) fake")
plt.plot(history_df["epoch"], history_df["D_G_z_gen"], label="D(G(z)) gen")
plt.xlabel("Epoch")
plt.ylabel("Probability")
plt.title("Discriminator Outputs During Training")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Como o D devolve logits, aplicas sigmoid para obter algo parecido com probabilidade.
#
# - `D(x):` Probabilidade média atribuída às imagens reais. (idealmente alta)
#
# - `D(G(z)) fake:` Probabilidade média atribuída às falsas quando treinas o D. (idealmente baixa)
#
# - `D(G(z)) gen:` Probabilidade média atribuída às falsas quando observadas no passo do G. (se começar a subir, pode indicar que o G está a enganar melhor o D)

# %% [markdown]
# # Gerar imagens a partir do último modelo em memória

# %%
netG.eval()
with torch.no_grad():
    noise = torch.randn(16, LATENT_DIM, 1, 1, device=DEVICE)
    fake_images = netG(noise).cpu()
    fake_images = (fake_images + 1) / 2

grid = make_grid(fake_images, nrow=4, padding=2)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis("off")
plt.show()

# %% [markdown]
# # Confirmar que os dados estão bem:

# %%
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

real_batch = next(iter(dataloader))
real_batch = real_batch[:16].cpu()
real_batch = (real_batch + 1) / 2  # volta de [-1,1] para [0,1]

grid = make_grid(real_batch, nrow=4, padding=2)
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis("off")
plt.show()

# %%
real_batch = next(iter(dataloader))
img = real_batch[0].cpu()
img = (img + 1) / 2  # [-1,1] -> [0,1]

import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.imshow(img.permute(1, 2, 0))
plt.axis("off")
plt.show()

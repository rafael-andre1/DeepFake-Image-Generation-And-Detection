# %% [markdown]
# # GAN - g0 baseline instrumented
#
# Esta versão mantém a DCGAN base, mas acrescenta a instrumentação necessária para a fase **g0**:
#
# - outputs separados por `RUN_NAME`;
# - histórico de treino em CSV;
# - samples fixos em PNG;
# - FID/KID quando `torchmetrics` estiver disponível;
# - interpolação latente no fim;
# - checkpoints selecionados em vez de checkpoint por epoch.
#
# **Importante:** nesta fase não há ainda EMA, SpectralNorm, mais folds, label smoothing ou alterações de learning rate. O objetivo é criar uma baseline mensurável.

# %%
import os
import json
import base64
import io
import math
import random
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.utils import save_image, make_grid


import sys
sys.path.append(str(Path.cwd().parent))

from utils import DeepFakeDataset, dcganFormat  # <-- your utils module

# %% [markdown]
# ## Config

# %%
# =========================================================
# Config - g0 baseline instrumented
# =========================================================
# Esta experiência é a baseline mensurável: mantém arquitetura e hiperparâmetros base.

RUN_NAME = "g0_baseline_instrumented_with_KID"

REAL_DIR = "../../deepfake_data/wiki"
BASE_OUTPUT_DIR = "outputs"
OUTPUT_DIR = os.path.join(BASE_OUTPUT_DIR, RUN_NAME)
SAMPLES_DIR = os.path.join(OUTPUT_DIR, "samples")
CHECKPOINTS_DIR = os.path.join(OUTPUT_DIR, "checkpoints")
PLOTS_DIR = os.path.join(OUTPUT_DIR, "plots")
METRICS_DIR = os.path.join(OUTPUT_DIR, "metrics")

IMAGE_SIZE = 64
BATCH_SIZE = 64
LATENT_DIM = 100
NGF = 64
NDF = 64
NUM_CHANNELS = 3

# Parâmetros de treino - baseline original
NUM_EPOCHS = 200
LR_G = 2e-4
LR_D = 1e-4
BETA1 = 0.5
SEED = 42
NUM_WORKERS = 0

# Folds usados na baseline g0. Não alterar nesta fase.
START_FOLD = 0
END_FOLD = 5
INTERVAL = True

# Logging / avaliação
SAMPLE_EVERY = 25          # guardar PNG com fixed_noise a cada N epochs
CHECKPOINT_EVERY = 5      # guardar checkpoint a cada N epochs
FID_EVERY = 50           # calcular FID/KID a cada N epochs
FID_NUM_IMAGES = 300      # ajustar para 2048/5000 se houver tempo/VRAM
SAVE_JSONL_EVERY = None   # usar 1 para guardar JSONL por epoch; None desliga JSONL
COMPUTE_KID = True

# Epochs extra que queremos sempre guardar, mesmo que não calhem no intervalo
ALWAYS_SAVE_EPOCHS = {1, NUM_EPOCHS}

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PIN_MEMORY = DEVICE.type == "cuda"

# Criar pastas dos outputs desta run
for folder in [OUTPUT_DIR, SAMPLES_DIR, CHECKPOINTS_DIR, PLOTS_DIR, METRICS_DIR]:
    os.makedirs(folder, exist_ok=True)

# Reprodutibilidade
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Mantém alguma performance. Para reprodutibilidade máxima, pôr benchmark=False e deterministic=True.
torch.backends.cudnn.benchmark = True

print("Run:", RUN_NAME)
print("Device:", DEVICE)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run: g0_baseline_instrumented_with_KID
# Device: cuda
# Output dir: outputs\g0_baseline_instrumented_with_KID

# %% [markdown]
# ## Utils

# %%
# =========================================================
# Utils de logging, samples e métricas
# =========================================================
from PIL import Image as PILImage


def denorm_to_01(x):
    """Converte tensores de [-1, 1] para [0, 1]."""
    return ((x + 1) / 2).clamp(0, 1)


def to_uint8_images(x):
    """Converte batch de imagens [-1,1] ou [0,1] para uint8 [0,255]."""
    if x.min() < 0:
        x = denorm_to_01(x)
    return (x * 255).clamp(0, 255).to(torch.uint8)


def should_run(epoch, every):
    if every is None:
        return False
    return epoch in ALWAYS_SAVE_EPOCHS or epoch % every == 0


def save_generated_samples_png(epoch, generator, noise, out_dir=SAMPLES_DIR, prefix="fixed_noise", nrow=8):
    """Guarda grelha PNG usando o fixed_noise."""
    generator.eval()
    with torch.no_grad():
        fake_images = denorm_to_01(generator(noise).detach().cpu())
        grid = make_grid(fake_images, nrow=nrow, padding=2, normalize=False)
        path = os.path.join(out_dir, f"{prefix}_epoch_{epoch:03d}.png")
        save_image(grid, path)
    generator.train()
    return path


def save_samples_jsonl(epoch, generator, noise, path, nrow=8):
    """Append one lossless-PNG sample grid (base64) as a JSON line.

    Útil se quiseres guardar uma evolução por epoch num formato único.
    Nesta versão g0 está desligado por defeito através de SAVE_JSONL_EVERY=None.
    """
    generator.eval()
    with torch.no_grad():
        fake = denorm_to_01(generator(noise).detach().cpu())
        grid = make_grid(fake, nrow=nrow, padding=2, normalize=False)
        arr = (grid.permute(1, 2, 0).numpy() * 255).clip(0, 255).astype("uint8")
        buf = io.BytesIO()
        PILImage.fromarray(arr).save(buf, format="PNG", optimize=True)
        b64 = base64.b64encode(buf.getvalue()).decode("ascii")
    generator.train()

    with open(path, "a") as f:
        f.write(json.dumps({"epoch": epoch, "format": "png", "grid_b64": b64}) + "\n")


def save_latent_interpolation(generator, latent_dim, device, out_path, steps=8, nrow=8):
    """Guarda uma interpolação linear entre dois vetores latentes."""
    generator.eval()
    z1 = torch.randn(1, latent_dim, 1, 1, device=device)
    z2 = torch.randn(1, latent_dim, 1, 1, device=device)
    alphas = torch.linspace(0, 1, steps=steps, device=device)
    z_interp = torch.cat([(1 - a) * z1 + a * z2 for a in alphas], dim=0)
    with torch.no_grad():
        imgs = denorm_to_01(generator(z_interp).detach().cpu())
        grid = make_grid(imgs, nrow=nrow, padding=2, normalize=False)
        save_image(grid, out_path)
    generator.train()
    return out_path


def save_real_grid(dataloader, out_path, n=16, nrow=4):
    """Guarda uma grelha de imagens reais para referência visual."""
    batch = next(iter(dataloader))[:n].cpu()
    batch = denorm_to_01(batch)
    grid = make_grid(batch, nrow=nrow, padding=2, normalize=False)
    save_image(grid, out_path)
    return out_path


# ---- FID / KID opcionais ----
try:
    from torchmetrics.image.fid import FrechetInceptionDistance
    from torchmetrics.image.kid import KernelInceptionDistance
    TORCHMETRICS_AVAILABLE = True
    print("torchmetrics disponível: FID/KID serão calculados.")
except Exception as e:
    FrechetInceptionDistance = None
    KernelInceptionDistance = None
    TORCHMETRICS_AVAILABLE = False
    print("torchmetrics não disponível: FID/KID serão ignorados.")
    print("Para ativar: pip install torchmetrics[image] torch-fidelity")
    print("Erro:", repr(e))


@torch.no_grad()
def compute_fid_kid(
    generator,
    dataloader,
    num_images=1024,
    latent_dim=LATENT_DIM,
    device=DEVICE,
    compute_kid=False,
):
    """Calcula FID e, opcionalmente, KID com torchmetrics.

    Para evitar bloqueios/memória excessiva no VS Code/Jupyter, o KID fica
    desligado por defeito. Quando compute_kid=False, a função nem instancia
    KernelInceptionDistance, evitando o buffer grande de features.
    """
    import gc

    if not TORCHMETRICS_AVAILABLE:
        return {"fid": float("nan"), "kid_mean": float("nan"), "kid_std": float("nan")}

    was_training = generator.training
    generator.eval()

    n_target = min(int(num_images), len(dataloader.dataset))
    if n_target <= 0:
        if was_training:
            generator.train()
        return {"fid": float("nan"), "kid_mean": float("nan"), "kid_std": float("nan")}

    fid = FrechetInceptionDistance(feature=2048).to(device)
    kid = None
    if compute_kid:
        # subset_size tem de ser <= número de imagens usadas.
        kid = KernelInceptionDistance(subset_size=min(50, n_target)).to(device)

    # Imagens reais
    seen = 0
    for real in dataloader:
        if isinstance(real, (list, tuple)):
            real = real[0]
        real = real.to(device, non_blocking=True)

        take = min(real.size(0), n_target - seen)
        if take <= 0:
            break

        real_u8 = to_uint8_images(real[:take])
        fid.update(real_u8, real=True)
        if kid is not None:
            kid.update(real_u8, real=True)
        seen += take

        del real, real_u8

    # Imagens falsas
    seen = 0
    while seen < n_target:
        b = min(BATCH_SIZE, n_target - seen)
        noise = torch.randn(b, latent_dim, 1, 1, device=device)
        fake = generator(noise)
        fake_u8 = to_uint8_images(fake)

        fid.update(fake_u8, real=False)
        if kid is not None:
            kid.update(fake_u8, real=False)
        seen += b

        del noise, fake, fake_u8

    fid_value = float(fid.compute().detach().cpu())

    if kid is not None:
        kid_mean, kid_std = kid.compute()
        kid_mean = float(kid_mean.detach().cpu())
        kid_std = float(kid_std.detach().cpu())
    else:
        kid_mean = float("nan")
        kid_std = float("nan")

    del fid, kid
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    if was_training:
        generator.train()

    return {
        "fid": fid_value,
        "kid_mean": kid_mean,
        "kid_std": kid_std,
    }
# Out:
# torchmetrics disponível: FID/KID serão calculados.

# %% [markdown]
# ## Dataset & DataLoader

# %%
dataset = DeepFakeDataset(
    img_dir=REAL_DIR,
    label=1,                           # ignored; image_only=True
    transform=dcganFormat(IMAGE_SIZE),
    range_folds=[START_FOLD, END_FOLD],
    interval=INTERVAL,
    image_only=True,                   # GAN mode: return only image tensor
)

dataloader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
    drop_last=True,
)

print(f"Total de imagens reais: {len(dataset)}")
print(f"Folds usados: {dataset.fold_names}")

# Guardar grelha de imagens reais para comparação visual
real_grid_path = save_real_grid(dataloader, os.path.join(SAMPLES_DIR, "real_reference_grid.png"))
print("Grelha real guardada em:", real_grid_path)
# Out:
# Building ../../deepfake_data/wiki dataset with 5 folds:   0%|          | 0/5 [00:00<?, ?it/s]
# Total de imagens reais: 1467
# Folds usados: ['00', '01', '02', '03', '04']
# Grelha real guardada em: outputs\g0_baseline_instrumented_with_KID\samples\real_reference_grid.png

# %% [markdown]
# ### Ver uma imagem do dataset

# %%
dataset.show(0)
# Out:
# img_shape=torch.Size([3, 64, 64]), img_type=<class 'torch.Tensor'>, label=None, fold=00, file=10049200_1891-09-16_1958.jpg
# tensor([[[ 0.7098,  0.7098,  0.7020,  ...,  0.2235,  0.3020,  0.3333],
#          [ 0.7098,  0.7020,  0.6941,  ...,  0.2392,  0.2471,  0.2863],
#          [ 0.6941,  0.7020,  0.6784,  ...,  0.2471,  0.2157,  0.2314],
#          ...,
#          [-0.0745, -0.0902, -0.1373,  ...,  0.0431,  0.0667,  0.0824],
#          [-0.0824, -0.1059, -0.1451,  ...,  0.0745,  0.1137,  0.1137],
#          [-0.0667, -0.0980, -0.1216,  ...,  0.1137,  0.1216,  0.1137]],
#
#         [[ 0.7176,  0.7176,  0.7020,  ...,  0.2000,  0.2706,  0.3020],
#          [ 0.7176,  0.7098,  0.6941,  ...,  0.2157,  0.2235,  0.2627],
#          [ 0.6941,  0.7020,  0.6863,  ...,  0.2471,  0.2157,  0.2235],
#          ...,
#          [-0.0980, -0.1216, -0.1686,  ...,  0.0196,  0.0353,  0.0510],
#          [-0.1059, -0.1294, -0.1608,  ...,  0.0431,  0.0824,  0.0824],
#          [-0.0980, -0.1216, -0.1451,  ...,  0.0824,  0.0902,  0.0824]],
#
#         [[ 0.6784,  0.6784,  0.6784,  ...,  0.1765,  0.2471,  0.2784],
#          [ 0.6863,  0.6784,  0.6706,  ...,  0.2157,  0.2157,  0.2549],
#          [ 0.6784,  0.6863,  0.6627,  ...,  0.2471,  0.2157,  0.2235],
#          ...,
#          [-0.0902, -0.1137, -0.1608,  ...,  0.0196,  0.0275,  0.0431],
#          [-0.0980, -0.1137, -0.1529,  ...,  0.0353,  0.0667,  0.0667],
#          [-0.0902, -0.1137, -0.1294,  ...,  0.0667,  0.0745,  0.0667]]])

# %% [markdown]
# ### Inicialização de pesos

# %%
# Esta função inicializa os pesos da rede, se for:
# - Camada convolucional: inicializa os pesos com distribuição normal (média 0 e desvio padrão 0.02)
# - Camada BatchNorm: pesos perto de 1 e bias 0 
def weights_init(m):
    classname = m.__class__.__name__
    if "Conv" in classname:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif "BatchNorm" in classname:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
# Isto é o tipo de inicialização clássica em DCGAN

# %% [markdown]
# # Gerador

# %%
# O Gerador recebe um vetor aleatório z e tenta convertê-lo numa imagem falsa realista
class Generator(nn.Module):
    def __init__(self, latent_dim=100, ngf=64, nc=3):
        super().__init__()

        self.init = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
        )

        self.main = nn.Sequential(
            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 8, ngf * 4, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 4, ngf * 2, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf * 2, ngf, 3, 1, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(ngf, nc, 3, 1, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        x = self.init(z)
        return self.main(x)

# %% [markdown]
# # Discriminador

# %%
# Recebe uma imagem e tenta dizer se ela é real ou falsa
# Ele faz o oposto do gerador, reduz progressivamente a resolução, aumentando profundidade e no fim produz um único valor por imagem
class Discriminator(nn.Module):
    def __init__(self, nc=3, ndf=64):
        super().__init__()
        self.main = nn.Sequential(
            # 64x64 -> 32x32
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            # 32x32 -> 16x16
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),

            # 16x16 -> 8x8
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),

            # 8x8 -> 4x4
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),

            # 4x4 -> 1x1
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False)
        )

    def forward(self, x):
        return self.main(x).view(-1)

# %% [markdown]
# # Instanciar modelos

# %%
netG = Generator(LATENT_DIM, NGF, NUM_CHANNELS).to(DEVICE)
netD = Discriminator(NUM_CHANNELS, NDF).to(DEVICE)

netG.apply(weights_init)
netD.apply(weights_init)

print(netG)
print(netD)
# Out:
# Generator(
#   (init): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (main): Sequential(
#     (0): Upsample(scale_factor=2.0, mode='nearest')
#     (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Upsample(scale_factor=2.0, mode='nearest')
#     (5): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace=True)
#     (8): Upsample(scale_factor=2.0, mode='nearest')
#     (9): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): Upsample(scale_factor=2.0, mode='nearest')
#     (13): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (14): Tanh()
#   )
# )
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   )
# )

# %%
# Loss binária com logits
# O discriminador devolve logits crus, sem sigmoid, esta loss combina sigmoid e binary cross entropy de forma mais estavel numericamente
criterion = nn.BCEWithLogitsLoss()

# Otimizadores Adam para o discriminador e o gerador
optimizerD = optim.Adam(netD.parameters(), lr=LR_D, betas=(BETA1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=LR_G, betas=(BETA1, 0.999))

# Ruido fixo para as amostras. Este ruido serve para gerar sempre as mesmas 64 imagens ao longo do treino.
# Deste modo podemos ver a evolução do gerador de forma consistente (na epoch 1, 10, 50, etc)
fixed_noise = torch.randn(64, LATENT_DIM, 1, 1, device=DEVICE)

# %% [markdown]
# ## Função para guardar amostras

# %%
# Wrapper compatível com versões anteriores do notebook
def save_generated_samples(epoch, generator, noise):
    return save_generated_samples_png(epoch, generator, noise)

# %% [markdown]
# ## Treino

# %%
print("CUDA available:", torch.cuda.is_available())
print("netG on:", next(netG.parameters()).device)
print("netD on:", next(netD.parameters()).device)
# Out:
# CUDA available: True
# netG on: cuda:0
# netD on: cuda:0

# %%
from tqdm.auto import tqdm

# =========================================================
# Treino - g0 baseline instrumented
# =========================================================
# Mantém o treino adversarial da baseline, mas guarda métricas e artefactos de forma organizada.

history = []
fid_history = []
g_losses, d_losses = [], []

history_path = os.path.join(METRICS_DIR, "training_history.csv")
fid_path = os.path.join(METRICS_DIR, "fid_kid_history.csv")
config_path = os.path.join(OUTPUT_DIR, "run_config.json")

run_config = {
    "run_name": RUN_NAME,
    "real_dir": REAL_DIR,
    "image_size": IMAGE_SIZE,
    "batch_size": BATCH_SIZE,
    "latent_dim": LATENT_DIM,
    "ngf": NGF,
    "ndf": NDF,
    "num_epochs": NUM_EPOCHS,
    "lr_g": LR_G,
    "lr_d": LR_D,
    "beta1": BETA1,
    "seed": SEED,
    "start_fold": START_FOLD,
    "end_fold": END_FOLD,
    "interval": INTERVAL,
    "sample_every": SAMPLE_EVERY,
    "checkpoint_every": CHECKPOINT_EVERY,
    "fid_every": FID_EVERY,
    "fid_num_images": FID_NUM_IMAGES,
    "compute_kid": COMPUTE_KID,
    "num_workers": NUM_WORKERS,
    "num_real_images": len(dataset),
    "folds_used": list(dataset.fold_names),
}
with open(config_path, "w") as f:
    json.dump(run_config, f, indent=2)

# JSONL opcional para evolução detalhada por epoch
if SAVE_JSONL_EVERY is not None:
    samples_jsonl_path = os.path.join(OUTPUT_DIR, "samples_evolution.jsonl")
    open(samples_jsonl_path, "w").close()
else:
    samples_jsonl_path = None

# Guardar samples iniciais antes do treino
save_generated_samples_png(0, netG, fixed_noise, prefix="fixed_noise_initial")

print("A começar treino g0...")
epoch_bar = tqdm(range(1, NUM_EPOCHS + 1), desc="Training", unit="epoch")

for epoch in epoch_bar:
    epoch_g_loss = 0.0
    epoch_d_loss = 0.0
    epoch_dx = 0.0
    epoch_dgz_fake = 0.0
    epoch_dgz_gen = 0.0

    batch_bar = tqdm(dataloader, desc=f"Epoch {epoch}", leave=False, unit="batch")
    for real_images in batch_bar:
        real_images = real_images.to(DEVICE)
        b_size = real_images.size(0)

        # --- Discriminator ---
        netD.zero_grad(set_to_none=True)
        output_real = netD(real_images)
        lossD_real = criterion(output_real, torch.ones(b_size, device=DEVICE))

        noise = torch.randn(b_size, LATENT_DIM, 1, 1, device=DEVICE)
        fake_images = netG(noise)
        output_fake = netD(fake_images.detach())
        lossD_fake = criterion(output_fake, torch.zeros(b_size, device=DEVICE))

        lossD = lossD_real + lossD_fake
        lossD.backward()
        optimizerD.step()

        # --- Generator ---
        netG.zero_grad(set_to_none=True)
        output_gen = netD(fake_images)
        lossG = criterion(output_gen, torch.ones(b_size, device=DEVICE))
        lossG.backward()
        optimizerG.step()

        # Métricas por batch
        with torch.no_grad():
            dx = torch.sigmoid(output_real).mean().item()
            dgz_fake = torch.sigmoid(output_fake).mean().item()
            dgz_gen = torch.sigmoid(output_gen).mean().item()

        epoch_d_loss += lossD.item()
        epoch_g_loss += lossG.item()
        epoch_dx += dx
        epoch_dgz_fake += dgz_fake
        epoch_dgz_gen += dgz_gen

        batch_bar.set_postfix(d=f"{lossD.item():.3f}", g=f"{lossG.item():.3f}", dx=f"{dx:.2f}")

    n = len(dataloader)
    avg_d = epoch_d_loss / n
    avg_g = epoch_g_loss / n
    avg_dx = epoch_dx / n
    avg_dgz_fake = epoch_dgz_fake / n
    avg_dgz_gen = epoch_dgz_gen / n

    d_losses.append(avg_d)
    g_losses.append(avg_g)

    row = {
        "run_name": RUN_NAME,
        "epoch": epoch,
        "loss_d": avg_d,
        "loss_g": avg_g,
        "D_x": avg_dx,
        "D_G_z_fake": avg_dgz_fake,
        "D_G_z_gen": avg_dgz_gen,
    }
    history.append(row)
    pd.DataFrame(history).to_csv(history_path, index=False)

    epoch_bar.set_postfix(loss_d=f"{avg_d:.3f}", loss_g=f"{avg_g:.3f}", d_x=f"{avg_dx:.2f}", dgz=f"{avg_dgz_gen:.2f}")

    # Samples PNG selecionadas
    if should_run(epoch, SAMPLE_EVERY):
        save_generated_samples_png(epoch, netG, fixed_noise, prefix="fixed_noise")

    # JSONL opcional
    if SAVE_JSONL_EVERY is not None and should_run(epoch, SAVE_JSONL_EVERY):
        save_samples_jsonl(epoch, netG, fixed_noise, samples_jsonl_path)

    # FID/KID selecionado
    if FID_EVERY is not None and (epoch % FID_EVERY == 0 or epoch == NUM_EPOCHS):
        metrics = compute_fid_kid(netG, dataloader, num_images=FID_NUM_IMAGES, compute_kid=COMPUTE_KID)
        metrics.update({"run_name": RUN_NAME, "epoch": epoch})
        fid_history.append(metrics)
        pd.DataFrame(fid_history).to_csv(fid_path, index=False)
        if COMPUTE_KID:
            print(f"Epoch {epoch:03d} | FID: {metrics['fid']:.3f} | KID: {metrics['kid_mean']:.5f} ± {metrics['kid_std']:.5f}")
        else:
            print(f"Epoch {epoch:03d} | FID: {metrics['fid']:.3f} | KID: desligado")

    # Checkpoints selecionados
    if should_run(epoch, CHECKPOINT_EVERY):
        torch.save({
            "epoch": epoch,
            "netG_state_dict": netG.state_dict(),
            "netD_state_dict": netD.state_dict(),
            "optimizerG_state_dict": optimizerG.state_dict(),
            "optimizerD_state_dict": optimizerD.state_dict(),
            "g_losses": g_losses,
            "d_losses": d_losses,
            "history": history,
            "fid_history": fid_history,
            "config": run_config,
        }, os.path.join(CHECKPOINTS_DIR, f"dcgan_{RUN_NAME}_epoch_{epoch:03d}.pt"))

# Artefactos finais
interpolation_path = save_latent_interpolation(
    netG,
    LATENT_DIM,
    DEVICE,
    os.path.join(SAMPLES_DIR, "latent_interpolation_final.png"),
    steps=8,
    nrow=8,
)
print("Treino terminado.")
print("Histórico:", history_path)
print("FID/KID:", fid_path)
print("Interpolação latente:", interpolation_path)
# Out:
# A começar treino g0...
# Training:   0%|          | 0/200 [00:00<?, ?epoch/s]
# Epoch 1:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 2:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 3:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 4:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 5:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 6:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 7:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 8:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 9:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 10:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 11:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 12:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 13:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 14:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 15:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 16:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 17:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 18:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 19:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 20:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 21:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 22:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 23:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 24:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 25:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 26:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 27:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 28:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 29:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 30:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 31:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 32:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 33:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 34:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 35:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 36:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 37:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 38:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 39:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 40:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 41:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 42:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 43:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 44:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 45:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 46:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 47:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 48:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 49:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 50:   0%|          | 0/22 [00:00<?, ?batch/s]
# c:\Users\User\MIA\DRL\Project\.venv\Lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Epoch 050 | FID: 328.877 | KID: 0.27846 ± 0.01319
# Epoch 51:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 52:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 53:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 54:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 55:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 56:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 57:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 58:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 59:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 60:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 61:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 62:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 63:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 64:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 65:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 66:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 67:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 68:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 69:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 70:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 71:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 72:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 73:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 74:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 75:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 76:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 77:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 78:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 79:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 80:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 81:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 82:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 83:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 84:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 85:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 86:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 87:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 88:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 89:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 90:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 91:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 92:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 93:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 94:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 95:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 96:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 97:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 98:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 99:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 100:   0%|          | 0/22 [00:00<?, ?batch/s]
# c:\Users\User\MIA\DRL\Project\.venv\Lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Epoch 100 | FID: 307.679 | KID: 0.22003 ± 0.01067
# Epoch 101:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 102:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 103:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 104:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 105:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 106:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 107:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 108:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 109:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 110:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 111:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 112:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 113:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 114:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 115:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 116:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 117:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 118:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 119:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 120:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 121:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 122:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 123:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 124:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 125:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 126:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 127:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 128:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 129:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 130:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 131:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 132:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 133:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 134:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 135:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 136:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 137:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 138:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 139:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 140:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 141:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 142:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 143:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 144:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 145:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 146:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 147:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 148:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 149:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 150:   0%|          | 0/22 [00:00<?, ?batch/s]
# c:\Users\User\MIA\DRL\Project\.venv\Lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Epoch 150 | FID: 300.439 | KID: 0.20040 ± 0.01172
# Epoch 151:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 152:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 153:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 154:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 155:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 156:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 157:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 158:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 159:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 160:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 161:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 162:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 163:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 164:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 165:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 166:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 167:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 168:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 169:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 170:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 171:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 172:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 173:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 174:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 175:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 176:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 177:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 178:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 179:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 180:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 181:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 182:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 183:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 184:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 185:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 186:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 187:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 188:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 189:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 190:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 191:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 192:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 193:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 194:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 195:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 196:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 197:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 198:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 199:   0%|          | 0/22 [00:00<?, ?batch/s]
# Epoch 200:   0%|          | 0/22 [00:00<?, ?batch/s]
# c:\Users\User\MIA\DRL\Project\.venv\Lib\site-packages\torchmetrics\utilities\prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Epoch 200 | FID: 307.240 | KID: 0.20134 ± 0.01175
# Treino terminado.
# Histórico: outputs\g0_baseline_instrumented_with_KID\metrics\training_history.csv
# FID/KID: outputs\g0_baseline_instrumented_with_KID\metrics\fid_kid_history.csv
# Interpolação latente: outputs\g0_baseline_instrumented_with_KID\samples\latent_interpolation_final.png
# Treino terminado.
# Histórico: outputs\g0_baseline_instrumented_with_KID\metrics\training_history.csv
# FID/KID: outputs\g0_baseline_instrumented_with_KID\metrics\fid_kid_history.csv
# Interpolação latente: outputs\g0_baseline_instrumented_with_KID\samples\latent_interpolation_final.png

# %%
import matplotlib.pyplot as plt

history_path = os.path.join(METRICS_DIR, "training_history.csv")
history_df = pd.read_csv(history_path)

plt.figure(figsize=(10, 5))
plt.plot(history_df["epoch"], history_df["loss_g"], label="Generator Loss")
plt.plot(history_df["epoch"], history_df["loss_d"], label="Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"GAN Training Losses - {RUN_NAME}")
plt.legend()
plt.grid(True)
loss_plot_path = os.path.join(PLOTS_DIR, "loss_curves.png")
plt.savefig(loss_plot_path, dpi=150, bbox_inches="tight")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history_df["epoch"], history_df["D_x"], label="D(x)")
plt.plot(history_df["epoch"], history_df["D_G_z_fake"], label="D(G(z)) fake")
plt.plot(history_df["epoch"], history_df["D_G_z_gen"], label="D(G(z)) gen")
plt.xlabel("Epoch")
plt.ylabel("Probability")
plt.title(f"Discriminator Outputs During Training - {RUN_NAME}")
plt.legend()
plt.grid(True)
d_plot_path = os.path.join(PLOTS_DIR, "discriminator_outputs.png")
plt.savefig(d_plot_path, dpi=150, bbox_inches="tight")
plt.show()

fid_path = os.path.join(METRICS_DIR, "fid_kid_history.csv")
if os.path.exists(fid_path):
    fid_df = pd.read_csv(fid_path)
    if "fid" in fid_df and fid_df["fid"].notna().any():
        plt.figure(figsize=(10, 5))
        plt.plot(fid_df["epoch"], fid_df["fid"], marker="o", label="FID")
        plt.xlabel("Epoch")
        plt.ylabel("FID")
        plt.title(f"FID vs Epoch - {RUN_NAME}")
        plt.legend()
        plt.grid(True)
        fid_plot_path = os.path.join(PLOTS_DIR, "fid_curve.png")
        plt.savefig(fid_plot_path, dpi=150, bbox_inches="tight")
        plt.show()
    else:
        print("FID existe, mas está vazio/NaN. Verificar torchmetrics/torch-fidelity.")
else:
    print("Ainda não existe ficheiro FID/KID. Corre o treino primeiro.")

print("Plots guardados em:", PLOTS_DIR)
# Out:
# Plots guardados em: outputs\g0_baseline_instrumented_with_KID\plots

# %%
fid_path = os.path.join(METRICS_DIR, "fid_kid_history.csv")

if os.path.exists(fid_path):
    fid_df = pd.read_csv(fid_path)

    # --- FID plot ---
    if "fid" in fid_df.columns and fid_df["fid"].notna().any():
        plt.figure(figsize=(10, 5))
        plt.plot(fid_df["epoch"], fid_df["fid"], marker="o", label="FID")
        plt.xlabel("Epoch")
        plt.ylabel("FID")
        plt.title(f"FID vs Epoch - {RUN_NAME}")
        plt.legend()
        plt.grid(True)

        fid_plot_path = os.path.join(PLOTS_DIR, "fid_curve.png")
        plt.savefig(fid_plot_path, dpi=150, bbox_inches="tight")
        plt.show()
    else:
        print("FID existe, mas está vazio/NaN. Verificar torchmetrics/torch-fidelity.")

    # --- KID plot, only if available ---
    if "kid_mean" in fid_df.columns and fid_df["kid_mean"].notna().any():
        plt.figure(figsize=(10, 5))
        plt.plot(fid_df["epoch"], fid_df["kid_mean"], marker="o", label="KID mean")

        if "kid_std" in fid_df.columns and fid_df["kid_std"].notna().any():
            lower = fid_df["kid_mean"] - fid_df["kid_std"]
            upper = fid_df["kid_mean"] + fid_df["kid_std"]
            plt.fill_between(fid_df["epoch"], lower, upper, alpha=0.2, label="KID ± std")

        plt.xlabel("Epoch")
        plt.ylabel("KID")
        plt.title(f"KID vs Epoch - {RUN_NAME}")
        plt.legend()
        plt.grid(True)

        kid_plot_path = os.path.join(PLOTS_DIR, "kid_curve.png")
        plt.savefig(kid_plot_path, dpi=150, bbox_inches="tight")
        plt.show()
    else:
        print("KID desligado ou sem valores válidos; a avaliação g0 usa FID como métrica principal.")

else:
    print("Ainda não existe ficheiro FID/KID. Corre o treino primeiro.")

print("Plots guardados em:", PLOTS_DIR)
# Out:
# Plots guardados em: outputs\g0_baseline_instrumented_with_KID\plots

# %% [markdown]
# Como o D devolve logits, aplicas sigmoid para obter algo parecido com probabilidade.
#
# - `D(x):` Probabilidade média atribuída às imagens reais. (idealmente alta)
#
# - `D(G(z)) fake:` Probabilidade média atribuída às falsas quando treinas o D. (idealmente baixa)
#
# - `D(G(z)) gen:` Probabilidade média atribuída às falsas quando observadas no passo do G. (se começar a subir, pode indicar que o G está a enganar melhor o D)

# %% [markdown]
# # Gerar imagens a partir do último modelo em memória

# %%
netG.eval()
with torch.no_grad():
    noise = torch.randn(16, LATENT_DIM, 1, 1, device=DEVICE)
    fake_images = denorm_to_01(netG(noise).cpu())

grid = make_grid(fake_images, nrow=4, padding=2)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis("off")
plt.show()

manual_sample_path = os.path.join(SAMPLES_DIR, "manual_random_samples.png")
save_image(grid, manual_sample_path)
print("Samples guardadas em:", manual_sample_path)
# Out:
# Samples guardadas em: outputs\g0_baseline_instrumented_with_KID\samples\manual_random_samples.png

# %% [markdown]
# # Confirmar que os dados estão bem:

# %%
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

real_batch = next(iter(dataloader))
real_batch = denorm_to_01(real_batch[:16].cpu())

grid = make_grid(real_batch, nrow=4, padding=2)
plt.figure(figsize=(8, 8))
plt.imshow(grid.permute(1, 2, 0))
plt.axis("off")
plt.show()

# %%
real_batch = next(iter(dataloader))
img = denorm_to_01(real_batch[0].cpu())

import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.imshow(img.permute(1, 2, 0))
plt.axis("off")
plt.show()

# %%
# Resumo rápido da run para copiar para o JOURNAL.md
summary = {
    "Iteration": "g0_baseline_instrumented",
    "Change": "DCGAN baseline + FID/KID logging + fixed samples + latent interpolation",
    "FID @ end": None,
    "Notes": "Baseline mensurável; sem EMA, sem SpectralNorm, sem alterações de LR/dados.",
}

fid_path = os.path.join(METRICS_DIR, "fid_kid_history.csv")
if os.path.exists(fid_path):
    fid_df = pd.read_csv(fid_path)
    if len(fid_df) > 0 and fid_df["fid"].notna().any():
        summary["FID @ end"] = float(fid_df.dropna(subset=["fid"]).iloc[-1]["fid"])

print(json.dumps(summary, indent=2, ensure_ascii=False))
# Out:
# {
#   "Iteration": "g0_baseline_instrumented",
#   "Change": "DCGAN baseline + FID/KID logging + fixed samples + latent interpolation",
#   "FID @ end": 307.24041748046875,
#   "Notes": "Baseline mensurável; sem EMA, sem SpectralNorm, sem alterações de LR/dados."
# }

# %% [markdown]
# # Conclusão

# %% [markdown]
# **FID:**
# - A baseline DCGAN reduziu o FID entre as epochs 50 e 150, mas a melhoria estabilizou e degradou ligeiramente até à epoch 200, sugerindo limitação da arquitetura/dados e possível saturação adversarial.
#
# **Discriminador:**
#
#      D(x) → sobe até ~0.98
#      D(G(z)) fake → desce para ~0.01–0.02
#      D(G(z)) gen → também fica muito baixo
#
# - Observámos que D(x) se aproxima de 1 enquanto D(G(z)) tende para valores próximos de 0. Isto indica que o discriminador se tornou demasiado forte, reduzindo o sinal útil para o gerador.
#
# **Imagens geradas na epoch 200:**
# - As imagens mostram que a DCGAN já aprendeu algumas propriedades globais: cores de pele, fundos, silhuetas, algumas regiões tipo rosto/cabeça, contraste geral de retratos.
# - Mas ainda há muitos problemas: rostos pouco, muito ruído, artefactos cromáticos fortes, baixa coerência facial, algumas imagens quase abstratas, pouca nitidez
# - Ou seja, visualmente está coerente com um FID alto.
# - A baseline aprende a distribuição geral de cores e composição de retratos, mas não consegue gerar faces realistas nem preservar estrutura facial consistente.
#
# **Interpolação Latente:**
# - A sequência parece quase uma transição entre manchas/ruído, não entre identidades ou faces claras. Isto sugere que:
#      - o espaço latente ainda não está bem estruturado
#      - o gerador não aprendeu uma manifold facial robusta
#      - há baixa qualidade e possível baixa diversidade útil
# - A interpolação latente da baseline mostra transições suaves em cor/textura, mas não em atributos faciais semânticos, indicando que o espaço latente ainda não codifica bem características humanas.

# %% [markdown]
# ---
#
# g0 - Baseline DCGAN instrumentada
#
# **Alteração:**
# Baseline DCGAN com logging completo, FID/KID, samples fixos e interpolação latente.
#
# **Resultado:**
# FID melhorou de ~328.8 na epoch 50 para ~300.4 na epoch 150, mas piorou para ~307.2 na epoch 200.
# As imagens geradas mostram estrutura global de retratos, mas faces pouco coerentes e muito ruído.
# O discriminador domina o treino: D(x) aproxima-se de 1 e D(G(z)) aproxima-se de 0.
#
# **Decisão:**
# Usar g0 como baseline. Próxima fase deve atacar limitação de dados e desequilíbrio adversarial.

# %% [markdown]
# | g0 | baseline_instrumented | DCGAN baseline + FID/KID logging + fixed samples + latent interpolation | Best FID ≈ 300.4 @ epoch 150; FID @ epoch 200 ≈ 307.2 | Baseline measurable. Generator learns rough portrait colors/layout but faces remain noisy. D dominates: D(x)→~0.98 and D(G(z))→~0.01. Proceed to more data and discriminator balancing. |
